# %% [markdown]
# # ODE 2 workbook submission
#
# ## 8.2 a)

# %% [markdown]
# ## 8.7 b)

# %% [markdown]
# ## 8.7 c)

# %% [markdown]
# ## 8.9 a)

# %% [markdown]
# ## 8.10 b)

# %% [markdown]
# ## 8.10 c)

# %% [markdown]
# ## 8.10 d)
