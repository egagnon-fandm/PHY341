# %% [markdown]
# # Eigenvalues workbook submission
#
# ## 6.9 b)

# %% [markdown]
# ## 6.9 c)

# %% [markdown]
# ## 6.21 a)

# %% [markdown]
# ## 6.21 c)

# %% [markdown]
# ## 6.21 d)

# %% [markdown]
# ## 6.21 e)
