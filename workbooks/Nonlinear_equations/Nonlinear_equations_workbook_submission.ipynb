# %% [markdown]
# # Nonlinear equations workbook submission
#
# ## 6.11 a)

# %% [markdown]
# ## 6.11 b)

# %% [markdown]
# ## 6.12 b)

# %% [markdown]
# ## 6.12 c)

# %% [markdown]
# ## 6.13 b)

# %% [markdown]
# ## 6.13 c)

# %% [markdown]
# ## 6.14 b)
