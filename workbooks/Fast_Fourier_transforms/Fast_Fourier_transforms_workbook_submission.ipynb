# %% [markdown]
# ## 7.3 a)

# %% [markdown]
# ## 7.3 b)

# %% [markdown]
# ## 7.4 a)

# %% [markdown]
# ## 7.4 b)

# %% [markdown]
# ## 7.4 c)

# %% [markdown]
# ## 7.4 d)

# %% [markdown]
# ## 7.4 e)
